# %% [markdown]
# # Hyperspectral data exploration - Water
#
# ## I.L. 21.10.2024

# %% [markdown]
# ## Goal
#
# In this notebook, we’ll walk through creating a basic interactive application using NumPy, Pandas, and hvPlot. If you haven’t installed hvPlot yet, you can do so with pip install hvplot or conda install -c conda-forge hvplot.
#
# Let’s envision what our app will look like:

# %% [markdown]
# ![](./GLORIA/GLORIA_plot.png)

# %% [markdown]
# ## Tools
#
# We will using [*Panel*](https://panel.holoviz.org/index.html), a Python library designed to streamline the development of robust tools, dashboards, and complex applications. Panel integrates seamlessly with the PyData ecosystem, offering powerful, interactive data tables, visualizations, and much more, to unlock, visualize, share, and collaborate on your data for efficient workflows.
#
# Panel is a component of the [*HoloViz*](https://holoviz.org/) ecosystem, providing a gateway to a cohesive suite of data exploration tools.

# %% [markdown]
# ### Fetching the data
#
# First, let’s import the necessary dependencies and define some variables:

# %%
import holoviews as hv
import hvplot.pandas
import numpy as np
import pandas as pd
import panel as pn

PRIMARY_COLOR = "#0072B5"
SECONDARY_COLOR = "#B54300"
TERCIARY_COLOR = "#50C878"
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e776b894-8a37-4d58-a6de-9a81de2ef0fb" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"26fa76d6-d3dd-4cdd-a310-7bc57d9109f8":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"ac5cd643376c47b5939c14333e998b8d","client_comm_id":"ba117a6d8b08464d86b220e52650afc4"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"26fa76d6-d3dd-4cdd-a310-7bc57d9109f8","roots":{"p1002":"e776b894-8a37-4d58-a6de-9a81de2ef0fb"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# Next, we’ll import the Panel JavaScript dependencies using pn.extension(...). For a visually appealing and responsive user experience, we’ll set the design to "material" and the sizing_mode to stretch_width:

# %%
pn.extension(design="material", sizing_mode="stretch_width")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='10fff51f-ef4a-4a92-9bf5-32b514e77356'>
#   <div id="ded90eb8-eeaa-4673-bb34-66c8c17d66eb" data-root-id="10fff51f-ef4a-4a92-9bf5-32b514e77356" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"db3d6ab6-c8ce-4027-8d7e-868fbf71d845":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"10fff51f-ef4a-4a92-9bf5-32b514e77356"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"9635c71d-c50c-4a1c-8e8c-61ca5bac22a8","attributes":{"plot_id":"10fff51f-ef4a-4a92-9bf5-32b514e77356","comm_id":"2b492835885f407f90eac75b207d5376","client_comm_id":"e8d05b7bd7cf4f76a7a72bdc6e0390f1"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"db3d6ab6-c8ce-4027-8d7e-868fbf71d845","roots":{"10fff51f-ef4a-4a92-9bf5-32b514e77356":"ded90eb8-eeaa-4673-bb34-66c8c17d66eb"},"root_ids":["10fff51f-ef4a-4a92-9bf5-32b514e77356"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ### GLORIA
#
# The GLObal Reflectance community dataset for Imaging and optical sensing of Aquatic environments (GLORIA) includes 7,572 curated hyperspectral remote sensing reflectance measurements at 1 nm intervals within the 350 to 900 nm wavelength range. In addition, at least one co-located water quality measurement of chlorophyll a, total suspended solids, absorption by dissolved substances, and Secchi depth, is provided.
#
# The GLORIA dataset is publicly available from [PANGAEA](https://doi.pangaea.de/10.1594/PANGAEA.948492)
#
# ![](./GLORIA/GLORIA.png)

# %% [markdown]
# Now, let’s load the GLORIA dataset that measured global water quality and hyperpectral signatures. We’ll speed up our application by caching (@pn.cache) the data across users:

# %%
CSV_FILE2 = (
    "./GLORIA/NGLORIA_Rrs.csv")

# %%
data = pd.read_csv(CSV_FILE2)

# %%
data.tail()
# Out:
#       Unnamed: 0 GLORIA_ID   Rrs_350   Rrs_351   Rrs_352   Rrs_353   Rrs_354  \
# 2995        5958  GID_6153       NaN       NaN       NaN       NaN       NaN
# 2996        5074  GID_5255       NaN       NaN       NaN       NaN       NaN
# 2997        4434  GID_4519       NaN       NaN       NaN       NaN       NaN
# 2998        1834  GID_1852  0.001164  0.001179  0.001194  0.001213  0.001234
# 2999        6339  GID_6535       NaN       NaN       NaN       NaN       NaN
#
#        Rrs_355   Rrs_356   Rrs_357  ...   Rrs_891   Rrs_892   Rrs_893  \
# 2995       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2996       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2997       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2998  0.001255  0.001279  0.001302  ...  0.000627  0.000627  0.000627
# 2999       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#        Rrs_894   Rrs_895   Rrs_896   Rrs_897   Rrs_898   Rrs_899   Rrs_900
# 2995       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2996       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2997       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2998  0.000627  0.000627  0.000627  0.000627  0.000627  0.000627  0.000627
# 2999       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 553 columns]

# %%
data.columns = data.columns.str.replace('Rrs_', '')

# %%
data.tail()
# Out:
#       Unnamed: 0 GLORIA_ID       350       351       352       353       354  \
# 2995        5958  GID_6153       NaN       NaN       NaN       NaN       NaN
# 2996        5074  GID_5255       NaN       NaN       NaN       NaN       NaN
# 2997        4434  GID_4519       NaN       NaN       NaN       NaN       NaN
# 2998        1834  GID_1852  0.001164  0.001179  0.001194  0.001213  0.001234
# 2999        6339  GID_6535       NaN       NaN       NaN       NaN       NaN
#
#            355       356       357  ...       891       892       893  \
# 2995       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2996       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2997       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2998  0.001255  0.001279  0.001302  ...  0.000627  0.000627  0.000627
# 2999       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#            894       895       896       897       898       899       900
# 2995       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2996       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2997       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2998  0.000627  0.000627  0.000627  0.000627  0.000627  0.000627  0.000627
# 2999       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 553 columns]

# %%
##### Analyzing GLORIA data #######
metadata = pd.read_csv("./GLORIA/GLORIA_meta_and_lab.csv", index_col="GLORIA_ID")

# %%
metadata.head()
# Out:
#           Organization_ID        Dataset_ID Sample_ID LIMNADES_ID  \
# GLORIA_ID
# GID_1               UT-TO  AlikasK_EE_UT-TO        53         NaN
# GID_2               UT-TO  AlikasK_EE_UT-TO        54         NaN
# GID_3               UT-TO  AlikasK_EE_UT-TO        55         NaN
# GID_4               UT-TO  AlikasK_EE_UT-TO        56         NaN
# GID_5               UT-TO  AlikasK_EE_UT-TO        57         NaN
#
#           LIMNADES_UID SeaBASS_ID  Data_collection_purpose  \
# GLORIA_ID
# GID_1              NaN        NaN                      3.0
# GID_2              NaN        NaN                      3.0
# GID_3              NaN        NaN                      3.0
# GID_4              NaN        NaN                      3.0
# GID_5              NaN        NaN                      3.0
#
#            Special_event_flag    Site_name  Country  ...        TSS_method  \
# GLORIA_ID                                            ...
# GID_1                     NaN  Lake Peipsi  Estonia  ...  ESS Method 340.2
# GID_2                     NaN  Lake Peipsi  Estonia  ...  ESS Method 340.2
# GID_3                     NaN  Lake Peipsi  Estonia  ...  ESS Method 340.2
# GID_4                     NaN  Lake Peipsi  Estonia  ...  ESS Method 340.2
# GID_5                     NaN  Lake Peipsi  Estonia  ...  ESS Method 340.2
#
#                   aCDOM_method  Chla Chla_plus_phaeo   TSS  aCDOM440  \
# GLORIA_ID
# GID_1      NASA TM 2003-211621   NaN            8.16  2.67  2.532844
# GID_2      NASA TM 2003-211621   NaN            8.60  5.67  2.624947
# GID_3      NASA TM 2003-211621   NaN            7.27  8.00  2.578895
# GID_4      NASA TM 2003-211621   NaN            7.30  7.00  3.085464
# GID_5      NASA TM 2003-211621   NaN           13.05  8.67  3.039412
#
#            Turbidity  Secchi_depth  AOT     Comments
# GLORIA_ID
# GID_1            NaN          1.85  NaN  Lake Peipsi
# GID_2            NaN          1.80  NaN  Lake Peipsi
# GID_3            NaN          1.80  NaN  Lake Peipsi
# GID_4            NaN          1.15  NaN  Lake Peipsi
# GID_5            NaN          1.00  NaN  Lake Peipsi
#
# [5 rows x 63 columns]

# %%
metadata.shape
# Out:
# (7572, 63)

# %% [markdown]
# ## Total Suspended Solids (TSS)
#
# ![](./GLORIA/TSS_TSD.png)

# %%
# selecting rows based on condition
a = metadata.index[metadata['TSS'] > 1000].tolist()

# %%
# selecting rows based on condition
#df[(df['age'] < 25) & df['name'].str.endswith('e')]
b = metadata.index[(metadata['TSS'] > 500) & (metadata['TSS'] < 1000)].tolist()

# %%
c = metadata.index[metadata['TSS'] < 1000].tolist()

# %%
@pn.cache
def get_data2():
  ##return pd.read_csv(CSV_FILE, parse_dates=["date"], index_col="date")
  data = pd.read_csv(CSV_FILE2,  index_col="GLORIA_ID")
  data.columns = data.columns.str.replace('Rrs_', '')
  return data

# %%
data3 = get_data2()

data3.tail()
# Out:
#            Unnamed: 0       350       351       352       353       354  \
# GLORIA_ID
# GID_6153         5958       NaN       NaN       NaN       NaN       NaN
# GID_5255         5074       NaN       NaN       NaN       NaN       NaN
# GID_4519         4434       NaN       NaN       NaN       NaN       NaN
# GID_1852         1834  0.001164  0.001179  0.001194  0.001213  0.001234
# GID_6535         6339       NaN       NaN       NaN       NaN       NaN
#
#                 355       356       357       358  ...       891       892  \
# GLORIA_ID                                          ...
# GID_6153        NaN       NaN       NaN       NaN  ...       NaN       NaN
# GID_5255        NaN       NaN       NaN       NaN  ...       NaN       NaN
# GID_4519        NaN       NaN       NaN       NaN  ...       NaN       NaN
# GID_1852   0.001255  0.001279  0.001302  0.001324  ...  0.000627  0.000627
# GID_6535        NaN       NaN       NaN       NaN  ...       NaN       NaN
#
#                 893       894       895       896       897       898  \
# GLORIA_ID
# GID_6153        NaN       NaN       NaN       NaN       NaN       NaN
# GID_5255        NaN       NaN       NaN       NaN       NaN       NaN
# GID_4519        NaN       NaN       NaN       NaN       NaN       NaN
# GID_1852   0.000627  0.000627  0.000627  0.000627  0.000627  0.000627
# GID_6535        NaN       NaN       NaN       NaN       NaN       NaN
#
#                 899       900
# GLORIA_ID
# GID_6153        NaN       NaN
# GID_5255        NaN       NaN
# GID_4519        NaN       NaN
# GID_1852   0.000627  0.000627
# GID_6535        NaN       NaN
#
# [5 rows x 552 columns]

# %% [markdown]
# ## Visualizing a Subset of the Data
#
# Before diving into Panel, let’s create a function that smooths one of our time series and identifies outliers. Then, we’ll plot the result using hvPlot:

# %%
data4 = data3[data3.index.isin(a)]

# %%
data5 = data4.mean(axis=0)

# %%
type(data5)
# Out:
# pandas.core.series.Series

# %%
def transform_data(variable, middle, high):
    """Calculates the rolling average and identifies outliers"""
    a = metadata.index[metadata[variable] > middle].tolist()
    b = metadata.index[(metadata[variable] > middle) & (metadata['TSS'] < high)].tolist()
    c = metadata.index[metadata[variable] < middle].tolist()
    data4 = data3[data3.index.isin(a)]
    avg1 = data4.mean(axis=0)
    data4 = data3[data3.index.isin(b)]
    avg2 = data4.mean(axis=0)
    data4 = data3[data3.index.isin(c)]
    avg3 = data4.mean(axis=0)
    return avg1, avg2, avg3

# %%
avg1, avg2, avg3 = transform_data('TSS', 500, 1000)

# %%
avg1
# Out:
# Unnamed: 0    2479.214286
# 350              0.010907
# 351              0.010977
# 352              0.011045
# 353              0.011118
#                  ...
# 896              0.040406
# 897              0.040348
# 898              0.040281
# 899              0.040203
# 900              0.040128
# Length: 552, dtype: float64

# %%
lista = ['400', '500', '600', '700', '800']

# %%
ttt = avg1[avg1.index.isin(lista)]

# %%
ttt['400']
# Out:
# np.float64(0.01424085353021408)

# %%
def get_plot(variable, middle,high):
    """Plots the average for each range"""
    avg1, avg2, avg3 = transform_data(variable, middle, high)
    lista = ['400', '500', '600', '700']
    #data = avg1[avg1.index.isin(lista)]
    #vlines = hv.VLines(data, lista)
    return avg1.hvplot(
        height=300, legend=True, color=PRIMARY_COLOR, line_width=3, label= variable + ' > ' + str(high)
    ) * avg2.hvplot(color=SECONDARY_COLOR, legend=True, label= str(middle) + ' < ' + variable + ' < ' + str(high)
                           ) * avg3.hvplot(color=TERCIARY_COLOR, legend=True, label= variable + ' < ' + str(middle)
                                          ).opts(title="Average reflectance")

# %% [markdown]
# Now, we can call our get_plot function with specific parameters to obtain a plot with a single set of parameters:

# %%
get_plot('TSS', 500,1000)
# Out:
# :Overlay
#    .Curve.TSS_greater_than_1000              :Curve   [index]   (0)
#    .Curve.A_500_less_than_TSS_less_than_1000 :Curve   [index]   (0)
#    .Curve.TSS_less_than_500                  :Curve   [index]   (0)

# %% [markdown]
# Great! Now, let’s explore how different values for window and sigma affect the plot. Instead of reevaluating the above cell multiple times, let’s use Panel to add interactive controls and quickly visualize the impact of different parameter values.

# %% [markdown]
# ## Exploring the Parameter Space
#
# Let’s create some Panel slider widgets to explore the range of parameter values:

# %%
variable_widget = pn.widgets.Select(name="variable", value="TSS", options=['TSS'])
high_widget = pn.widgets.IntSlider(name="high", value=1000, start=800, end=1200)
middle_widget = pn.widgets.IntSlider(name="middle", value=500, start=100, end=500)

# %% [markdown]
# Now, let’s link these widgets to our plotting function so that updates to the widgets rerun the function. We can achieve this easily in Panel using pn.bind:

# %%
bound_plot = pn.bind(
    get_plot, variable=variable_widget, high=high_widget, middle=middle_widget
)

# %% [markdown]
# Once we’ve bound the widgets to the function’s arguments, we can layout the resulting bound_plot component along with the widgets using a Panel layout such as Column:

# %%
widgets = pn.Column(variable_widget, high_widget, middle_widget, sizing_mode="fixed", width=300)
pn.Column(widgets, bound_plot)
# Out:
# Column(design=<class 'panel.theme.materi..., sizing_mode='stretch_width')
#     [0] Column(design=<class 'panel.theme.materi..., sizing_mode='fixed', width=300)
#         [0] Select(design=<class 'panel.theme.materi..., name='variable', options=['TSS'], sizing_mode='stretch_width', value='TSS')
#         [1] IntSlider(design=<class 'panel.theme.materi..., end=1200, name='high', sizing_mode='stretch_width', start=800, value=1000)
#         [2] IntSlider(design=<class 'panel.theme.materi..., end=500, name='middle', sizing_mode='stretch_width', start=100, value=500)
#     [1] ParamFunction(function, _pane=HoloViews, defer_load=False, design=<class 'panel.theme.materi..., sizing_mode='stretch_width')

# %% [markdown]
# As long as you have a live Python process running, dragging these widgets will trigger a call to the get_plot callback function, evaluating it for whatever combination of parameter values you select and displaying the results.

# %% [markdown]
# ## Optional - Serving the Notebook
#
# You may be interested in serving the notebook. In such a case, uncomment the next  chunk of code and run it. Then, write the code to serve the notebook.

# %%
# Uncomment if needed
#pn.template.MaterialTemplate(
#   site="Panel",
#  title="GLORIA App",
#    sidebar=[variable_widget, high_widget, middle_widget],
#    main=[bound_plot],
#).servable(); # The ; is needed in the notebook to not display the template. Its not needed in a script

# %%
# Write the code based on # See https://panel.holoviz.org/tutorials/intermediate/serve.html
